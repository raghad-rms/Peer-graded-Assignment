# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Raghad Mahmoud Salah**
# Junior Data Analyst

# %% [markdown]
# *I am interested in  data science because I enjoy using practical methods to solve complex problems. I'm excited about applying data analysis to a new industry. I'm enthusiastic about data science, especially considering how quickly technology is changing the profession.*

# %% [markdown]
# ### Multiplying number 6 and 5

# %%
6*5
# Out:
# 30

# %% [markdown]
# Bulleted List
# * First bullet
# * Second bullet
#     * First sub bullet
#     * Second sub bullet
#
# Table
# |header|header|
# |----|----|
# |cell|cell|
# |cell|cell|
# |cell|cell|
#
# Numbered list
# 1. First line
# 2. second line
#     1. sub line
#
#
# Image
# ![ABT229849A545760742D0132DB74EC09B0A0E010B6739C284DB5231F88CE3DBB338.jpg](attachment:5d39a961-956a-4617-9c4a-280e9b5ad8cd.jpg)
